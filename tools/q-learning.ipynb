# %%
from replay_reader import read_snoopy, parse_bullets, width, height, player_r, bullet_r

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# %%
def feats(row, player):
    pos = np.array([row[f'x{player}'] / width, row[f'y{player}'] / height])
    pos_score = (1 - 4 * (pos[0] - 0.5) ** 2 +
                 np.log(2 / 3 - abs(pos[1] - 2 / 3) + 0.01))
    
    bullets = parse_bullets(row['bullets'])
    if bullets.empty:
        bullet_score = 0
    else:
        bullets['x'] /= width
        bullets['y'] /= height
        leeway = (player_r + bullet_r) / max(width, height)
        bullet_score = sum(np.log(np.linalg.norm(vec - pos) - leeway) for vec in bullets.query(f'player != "Player {player}"')[['x', 'y']].values)
    
    curr_angle = np.arctan2(row[f'y{3-player}'] - row[f'y{player}'],
                            row[f'x{3-player}'] - row[f'x{player}'])
    orientation_score = np.pi * 2 - abs(row[f'a{player}'] - curr_angle)
    
    return (pos_score, bullet_score, orientation_score)

# %%
def feat_df(game_df):
    rows = []
    for row in game_df.to_dict(orient='records'):
        pos, bullets, angle = feats(row, 1)
        pos2, bullets2, angle2 = feats(row, 2)
        rows.append({
            'pos1': pos,
            'bullet1': bullets,
            'orient1': angle,
            'pos2': pos2,
            'bullet2': bullets2,
            'orient2': angle2
        })
    return pd.DataFrame(rows)

# %%
class QLearner:
    def __init__(self, pos=0.0, bullets=0.0, angle=0.0, courage=1.0):
        self.pos = pos
        self.bullets = bullets
        self.angle = angle
        self.courage = courage
        
    def learn(self, f_df, winner, alpha=0.01, gamma=0.9):
        final_time = max(f_df.index)
        s = {}
        for index in f_df[~f_df.isna().any(axis=1)].index:
            for i in (1, 2):
                s[i] = np.sum(np.array([self.pos, self.bullets, self.angle]) * f_df.loc[index, [f'pos{i}', f'bullet{i}', f'orient{i}']].values)
            for i in (1, 2):
                real_q = gamma ** (final_time - index) * (1 if winner == i else -1)
                q = self.courage * s[i] - s[3 - i]
                print(real_q, q, self)
                delta = real_q - q
                # courage is really just adding new features with the same weights: it's a hyperparameter, not a parameter
                self.pos += alpha * delta * self.courage * f_df.loc[index, f'pos{i}']
                self.pos -= alpha * delta * f_df.loc[index, f'pos{3-i}']
                self.bullets += alpha * delta * self.courage * f_df.loc[index, f'bullet{i}']
                self.bullets -= alpha * delta * f_df.loc[index, f'bullet{3-i}']
                self.angle += alpha * delta * self.courage * f_df.loc[index, f'orient{i}']
                self.angle -= alpha * delta * f_df.loc[index, f'orient{3-i}']
                
        return (self.pos, self.bullets, self.angle)
    
    def __repr__(self):
        return f"QLearner(pos={self.pos:.2}, bullets={self.bullets:.2}, angle={self.angle:.2}, courage={self.courage:.2})"

# %%
q = QLearner()
for n_round, i in tqdm(enumerate(range(1, 41))):
    print(f"Game {i}")
    g = read_snoopy(f'../replays/game{i}.snoopy')
    if g.result != 0:
        winner = 1 if g.result == 1 else -1
        q.learn(feat_df(g.to_df()), winner, alpha=1/(10 + n_round))
        print(q)
# Out:
# 0it [00:00, ?it/s]
# Game 1
# 1it [00:00,  2.73it/s]
# 0.0011790184577738603 0.0 QLearner(pos=0.0, bullets=0.0, angle=0.0, courage=1.0)
# -0.0011790184577738603 0.0 QLearner(pos=7.1e-05, bullets=0.0, angle=-0.00028, courage=1.0)
# 0.0013100205086376223 0.0014032911934899735 QLearner(pos=0.00014, bullets=0.0, angle=-0.00056, courage=1.0)
# -0.0013100205086376223 -0.0014032911934899735 QLearner(pos=0.00014, bullets=0.0, angle=-0.00054, courage=1.0)
# 0.0014555783429306916 0.0012895691893319349 QLearner(pos=0.00013, bullets=0.0, angle=-0.00051, courage=1.0)
# -0.0014555783429306916 -0.0012895691893319349 QLearner(pos=0.00014, bullets=0.0, angle=-0.00055, courage=1.0)
# 0.0016173092699229906 0.0014807961171382413 QLearner(pos=0.00015, bullets=0.0, angle=-0.00059, courage=1.0)
# -0.0016173092699229906 -0.0014807961171382413 QLearner(pos=0.00016, bullets=0.0, angle=-0.00062, courage=1.0)
# 0.001797010299914434 0.0016336425403777409 QLearner(pos=0.00017, bullets=0.0, angle=-0.00066, courage=1.0)
# -0.001797010299914434 -0.0016336425403777409 QLearner(pos=0.00018, bullets=0.0, angle=-0.00069, courage=1.0)
# 0.0019966781110160375 0.0018131175728004487 QLearner(pos=0.00019, bullets=0.0, angle=-0.00073, courage=1.0)
# -0.0019966781110160375 -0.0018131175728004487 QLearner(pos=0.0002, bullets=0.0, angle=-0.00077, courage=1.0)
# 0.002218531234462264 0.0020090548267361575 QLearner(pos=0.00021, bullets=0.0, angle=-0.00082, courage=1.0)
# -0.002218531234462264 -0.0020090548267361575 QLearner(pos=0.00023, bullets=0.0, angle=-0.00086, courage=1.0)
# 0.002465034704958071 0.0022271718348744743 QLearner(pos=0.00024, bullets=0.0, angle=-0.00091, courage=1.0)
# -0.002465034704958071 -0.0022271718348744743 QLearner(pos=0.00026, bullets=0.0, angle=-0.00097, courage=1.0)
# 0.002738927449953412 0.002467301840941548 QLearner(pos=0.00027, bullets=0.0, angle=-0.001, courage=1.0)
# -0.002738927449953412 -0.002467301840941548 QLearner(pos=0.00029, bullets=0.0, angle=-0.0011, courage=1.0)
# 0.0030432527221704577 0.0027332661855039115 QLearner(pos=0.00031, bullets=0.0, angle=-0.0011, courage=1.0)
# -0.0030432527221704577 -0.0027332661855039115 QLearner(pos=0.00033, bullets=0.0, angle=-0.0012, courage=1.0)
# 0.0033813919135227306 0.0030272494626994817 QLearner(pos=0.00035, bullets=0.0, angle=-0.0013, courage=1.0)
# -0.0033813919135227306 -0.0030272494626994817 QLearner(pos=0.00038, bullets=0.0, angle=-0.0014, courage=1.0)
# 0.0037571021261363674 0.0033528057714322618 QLearner(pos=0.00041, bullets=0.0, angle=-0.0014, courage=1.0)
# -0.0037571021261363674 -0.0033528057714322618 QLearner(pos=0.00044, bullets=0.0, angle=-0.0015, courage=1.0)
# 0.004174557917929297 0.00371312187586956 QLearner(pos=0.00047, bullets=0.0, angle=-0.0016, courage=1.0)
# -0.004174557917929297 -0.00371312187586956 QLearner(pos=0.0005, bullets=0.0, angle=-0.0017, courage=1.0)
# 0.004638397686588108 0.004112971654431795 QLearner(pos=0.00054, bullets=0.0, angle=-0.0018, courage=1.0)
# -0.004638397686588108 -0.004112971654431795 QLearner(pos=0.00058, bullets=0.0, angle=-0.0019, courage=1.0)
# 0.00515377520732012 0.004556328549785687 QLearner(pos=0.00062, bullets=0.0, angle=-0.002, courage=1.0)
# -0.00515377520732012 -0.004556328549785687 QLearner(pos=0.00067, bullets=0.0, angle=-0.0021, courage=1.0)
# 0.005726416897022355 0.005048643116277298 QLearner(pos=0.00072, bullets=0.0, angle=-0.0023, courage=1.0)
# -0.005726416897022355 -0.005048643116277298 QLearner(pos=0.00078, bullets=0.0, angle=-0.0024, courage=1.0)
# 0.00636268544113595 0.0055961085892363704 QLearner(pos=0.00084, bullets=0.0, angle=-0.0025, courage=1.0)
# -0.00636268544113595 -0.0055961085892363704 QLearner(pos=0.00091, bullets=-8.5e-06, angle=-0.0027, courage=1.0)
# 0.007069650490151055 0.006212939939732286 QLearner(pos=0.00097, bullets=-1.7e-05, angle=-0.0028, courage=1.0)
# -0.007069650490151055 -0.006212939939732286 QLearner(pos=0.0011, bullets=-4.4e-05, angle=-0.003, courage=1.0)
# 0.00785516721127895 0.006919002330295517 QLearner(pos=0.0011, bullets=-7.1e-05, angle=-0.0031, courage=1.0)
# -0.00785516721127895 -0.006919002330295517 QLearner(pos=0.0012, bullets=-0.00012, angle=-0.0033, courage=1.0)
# 0.008727963568087723 0.007725095674261044 QLearner(pos=0.0013, bullets=-0.00016, angle=-0.0035, courage=1.0)
# -0.008727963568087723 -0.007725095674261044 QLearner(pos=0.0014, bullets=-0.00023, angle=-0.0037, courage=1.0)
# 0.009697737297875247 0.00863874803322605 QLearner(pos=0.0015, bullets=-0.0003, angle=-0.0039, courage=1.0)
# -0.009697737297875247 -0.00863874803322605 QLearner(pos=0.0016, bullets=-0.00038, angle=-0.004, courage=1.0)
# 0.01077526366430583 0.009665213094728679 QLearner(pos=0.0017, bullets=-0.00047, angle=-0.0042, courage=1.0)
# -0.01077526366430583 -0.009665213094728679 QLearner(pos=0.0018, bullets=-0.00057, angle=-0.0044, courage=1.0)
# 0.011972515182562033 0.011394187518416017 QLearner(pos=0.0019, bullets=-0.00068, angle=-0.0046, courage=1.0)
# -0.011972515182562033 -0.011394187518416017 QLearner(pos=0.002, bullets=-0.00074, angle=-0.0047, courage=1.0)
# 0.013302794647291146 0.012712186379031893 QLearner(pos=0.0021, bullets=-0.0008, angle=-0.0048, courage=1.0)
# -0.013302794647291146 -0.012712186379031893 QLearner(pos=0.0021, bullets=-0.00087, angle=-0.005, courage=1.0)
# 0.014780882941434608 0.014812238209427092 QLearner(pos=0.0022, bullets=-0.00094, angle=-0.0051, courage=1.0)
# -0.014780882941434608 -0.014812238209427092 QLearner(pos=0.0022, bullets=-0.00094, angle=-0.0051, courage=1.0)
# 0.016423203268260675 0.01547333802709083 QLearner(pos=0.0022, bullets=-0.00093, angle=-0.0051, courage=1.0)
# -0.016423203268260675 -0.01547333802709083 QLearner(pos=0.0023, bullets=-0.0011, angle=-0.0053, courage=1.0)
# 0.01824800363140075 0.017888276303544854 QLearner(pos=0.0024, bullets=-0.0012, angle=-0.0055, courage=1.0)
# -0.01824800363140075 -0.017888276303544854 QLearner(pos=0.0024, bullets=-0.0012, angle=-0.0056, courage=1.0)
# 0.020275559590445275 0.0191009603686488 QLearner(pos=0.0025, bullets=-0.0013, angle=-0.0057, courage=1.0)
# -0.020275559590445275 -0.0191009603686488 QLearner(pos=0.0026, bullets=-0.0015, angle=-0.006, courage=1.0)
# 0.022528399544939195 0.021630666804700622 QLearner(pos=0.0027, bullets=-0.0017, angle=-0.0063, courage=1.0)
# -0.022528399544939195 -0.021630666804700622 QLearner(pos=0.0028, bullets=-0.0018, angle=-0.0065, courage=1.0)
# 0.025031555049932437 0.022833218278439326 QLearner(pos=0.0029, bullets=-0.002, angle=-0.0067, courage=1.0)
# -0.025031555049932437 -0.022833218278439326 QLearner(pos=0.0032, bullets=-0.0023, angle=-0.0072, courage=1.0)
# 0.027812838944369374 0.025532307461131318 QLearner(pos=0.0035, bullets=-0.0027, angle=-0.0078, courage=1.0)
# -0.027812838944369374 -0.025532307461131318 QLearner(pos=0.0037, bullets=-0.003, angle=-0.0083, courage=1.0)
# 0.030903154382632636 0.029819689464592805 QLearner(pos=0.004, bullets=-0.0033, angle=-0.0088, courage=1.0)
# -0.030903154382632636 -0.029819689464592805 QLearner(pos=0.0041, bullets=-0.0035, angle=-0.0091, courage=1.0)
# 0.03433683820292515 0.030608189865735803 QLearner(pos=0.0043, bullets=-0.0037, angle=-0.0093, courage=1.0)
# -0.03433683820292515 -0.030608189865735803 QLearner(pos=0.0047, bullets=-0.0041, angle=-0.01, courage=1.0)
# 0.038152042447694615 0.03945661327524909 QLearner(pos=0.0052, bullets=-0.0045, angle=-0.011, courage=1.0)
# -0.038152042447694615 -0.03945661327524909 QLearner(pos=0.005, bullets=-0.0044, angle=-0.011, courage=1.0)
# 0.04239115827521624 0.038301499001288666 QLearner(pos=0.0048, bullets=-0.0042, angle=-0.01, courage=1.0)
# -0.04239115827521624 -0.038301499001288666 QLearner(pos=0.0054, bullets=-0.0049, angle=-0.011, courage=1.0)
# 0.047101286972462485 0.04861977250988048 QLearner(pos=0.0059, bullets=-0.0056, angle=-0.012, courage=1.0)
# -0.047101286972462485 -0.04861977250988048 QLearner(pos=0.0057, bullets=-0.0053, angle=-0.012, courage=1.0)
# 0.05233476330273609 0.04771138609562199 QLearner(pos=0.0055, bullets=-0.005, angle=-0.012, courage=1.0)
# -0.05233476330273609 -0.04771138609562199 QLearner(pos=0.0061, bullets=-0.0062, angle=-0.013, courage=1.0)
# 0.058149737003040096 0.06370741133853441 QLearner(pos=0.0067, bullets=-0.0074, angle=-0.014, courage=1.0)
# -0.058149737003040096 -0.06370741133853441 QLearner(pos=0.0059, bullets=-0.0057, angle=-0.012, courage=1.0)
# 0.06461081889226677 0.04460253994312742 QLearner(pos=0.0052, bullets=-0.0041, angle=-0.011, courage=1.0)
# -0.06461081889226677 -0.04460253994312742 QLearner(pos=0.0078, bullets=-0.0095, angle=-0.016, courage=1.0)
# 0.0717897987691853 0.11016955864783852 QLearner(pos=0.01, bullets=-0.015, angle=-0.021, courage=1.0)
# -0.0717897987691853 -0.11016955864783852 QLearner(pos=0.0054, bullets=-0.0037, angle=-0.011, courage=1.0)
# 0.07976644307687256 -0.02038962156661913 QLearner(pos=0.00032, bullets=0.0077, angle=-0.0014, courage=1.0)
# -0.07976644307687256 0.02038962156661913 QLearner(pos=0.014, bullets=-0.024, angle=-0.027, courage=1.0)
# 0.08862938119652507 0.3558757712056507 QLearner(pos=0.027, bullets=-0.056, angle=-0.052, courage=1.0)
# -0.08862938119652507 -0.3558757712056507 QLearner(pos=-0.009, bullets=0.035, angle=0.015, courage=1.0)
# 0.09847709021836118 -0.7239790105453462 QLearner(pos=-0.045, bullets=0.12, angle=0.083, courage=1.0)
# -0.09847709021836118 0.7239790105453462 QLearner(pos=0.067, bullets=-0.17, angle=-0.12, courage=1.0)
# 0.10941898913151242 2.8727082863360156 QLearner(pos=0.18, bullets=-0.47, angle=-0.33, courage=1.0)
# -0.10941898913151242 -2.8727082863360156 QLearner(pos=-0.2, bullets=0.57, angle=0.36, courage=1.0)
# 0.12157665459056935 -9.97898650985398 QLearner(pos=-0.59, bullets=1.6, angle=1.1, courage=1.0)
# -0.12157665459056935 9.97898650985398 QLearner(pos=0.83, bullets=-2.4, angle=-1.6, courage=1.0)
# 0.13508517176729928 39.78829572214778 QLearner(pos=2.2, bullets=-6.3, angle=-4.3, courage=1.0)
# -0.13508517176729928 -39.78829572214778 QLearner(pos=-3.4, bullets=9.6, angle=6.2, courage=1.0)
# 0.15009463529699918 -161.6335912712819 QLearner(pos=-9.0, bullets=2.5e+01, angle=1.7e+01, courage=1.0)
# -0.15009463529699918 161.6335912712819 QLearner(pos=1.4e+01, bullets=-4.1e+01, angle=-2.6e+01, courage=1.0)
# 0.16677181699666577 691.1420853085353 QLearner(pos=3.8e+01, bullets=-1.1e+02, angle=-6.9e+01, courage=1.0)
# -0.16677181699666577 -691.1420853085353 QLearner(pos=-6.4e+01, bullets=1.8e+02, angle=1.1e+02, courage=1.0)
# 0.18530201888518416 -3153.3785349754326 QLearner(pos=-1.6e+02, bullets=4.8e+02, angle=3e+02, courage=1.0)
# -0.18530201888518416 3153.3785349754326 QLearner(pos=3.1e+02, bullets=-9.3e+02, angle=-5.4e+02, courage=1.0)
# 0.20589113209464907 15950.861058936298 QLearner(pos=7.7e+02, bullets=-2.3e+03, angle=-1.4e+03, courage=1.0)
# -0.20589113209464907 -15950.861058936298 QLearner(pos=-1.6e+03, bullets=5.1e+03, angle=3e+03, courage=1.0)
# 0.2287679245496101 -91218.07070876683 QLearner(pos=-4.1e+03, bullets=1.3e+04, angle=7.5e+03, courage=1.0)
# -0.2287679245496101 91218.07070876683 QLearner(pos=1e+04, bullets=-3.4e+04, angle=-1.8e+04, courage=1.0)
# 0.2541865828329001 581517.7423327516 QLearner(pos=2.4e+04, bullets=-8.1e+04, angle=-4.3e+04, courage=1.0)
# -0.2541865828329001 -581517.7423327516 QLearner(pos=-6.8e+04, bullets=2.3e+05, angle=1.2e+05, courage=1.0)
# 0.2824295364810001 -3901509.497794641 QLearner(pos=-1.6e+05, bullets=5.3e+05, angle=2.8e+05, courage=1.0)
# -0.2824295364810001 3901509.497794641 QLearner(pos=4.7e+05, bullets=-1.6e+06, angle=-8e+05, courage=1.0)
# 0.31381059609000006 27120582.03309379 QLearner(pos=1.1e+06, bullets=-3.7e+06, angle=-1.9e+06, courage=1.0)
# -0.31381059609000006 -27120582.03309379 QLearner(pos=-3.4e+06, bullets=1.1e+07, angle=5.3e+06, courage=1.0)
# 0.3486784401000001 -193615516.24453592 QLearner(pos=-7.9e+06, bullets=2.6e+07, angle=1.2e+07, courage=1.0)
# -0.3486784401000001 193615516.24453592 QLearner(pos=2.5e+07, bullets=-8.3e+07, angle=-3.6e+07, courage=1.0)
# 0.3874204890000001 1444388796.0588331 QLearner(pos=5.9e+07, bullets=-1.9e+08, angle=-8.5e+07, courage=1.0)
# -0.3874204890000001 -1444388796.0588331 QLearner(pos=-2e+08, bullets=6.6e+08, angle=2.6e+08, courage=1.0)
# 0.4304672100000001 -9603957766.94026 QLearner(pos=-4.5e+08, bullets=1.5e+09, angle=6.1e+08, courage=1.0)
# -0.4304672100000001 9603957766.94026 QLearner(pos=1.3e+09, bullets=-3.1e+09, angle=-1.8e+09, courage=1.0)
# 0.4782969000000001 53263512572.80008 QLearner(pos=3.1e+09, bullets=-7.7e+09, angle=-4.2e+09, courage=1.0)
# -0.4782969000000001 -53263512572.80008 QLearner(pos=-7e+09, bullets=1.7e+10, angle=9.8e+09, courage=1.0)
# 0.531441 -281906635980.04987 QLearner(pos=-1.7e+10, bullets=4.3e+10, angle=2.4e+10, courage=1.0)
# -0.531441 281906635980.04987 QLearner(pos=3.9e+10, bullets=-7.8e+10, angle=-5.4e+10, courage=1.0)
# 0.5904900000000001 1619500046481.3335 QLearner(pos=9.4e+10, bullets=-2e+11, angle=-1.3e+11, courage=1.0)
# -0.5904900000000001 -1619500046481.3335 QLearner(pos=-2.4e+11, bullets=5e+11, angle=5.6e+11, courage=1.0)
# 0.6561 -12149325041356.395 QLearner(pos=-5.8e+11, bullets=1.2e+12, angle=1.2e+12, courage=1.0)
# -0.6561 12149325041356.395 QLearner(pos=2.2e+12, bullets=-4.5e+12, angle=-3.8e+12, courage=1.0)
# 0.7290000000000001 101310645583452.03 QLearner(pos=5e+12, bullets=-1e+13, angle=-8.8e+12, courage=1.0)
# -0.7290000000000001 -101310645583452.03 QLearner(pos=-2.1e+13, bullets=4.1e+13, angle=3.4e+13, courage=1.0)
# 0.81 -944949623134053.1 QLearner(pos=-4.6e+13, bullets=9.2e+13, angle=7.8e+13, courage=1.0)
# -0.81 944949623134053.1 QLearner(pos=2.2e+14, bullets=-4.1e+14, angle=-3.3e+14, courage=1.0)
# 0.9 9739392668370032.0 QLearner(pos=4.8e+14, bullets=-9.1e+14, angle=-7.3e+14, courage=1.0)
# -0.9 -9739392668370032.0 QLearner(pos=-2.6e+15, bullets=4.6e+15, angle=3.4e+15, courage=1.0)
# 1.0 -1.1367273386013248e+17 QLearner(pos=-5.7e+15, bullets=1e+16, angle=7.6e+15, courage=1.0)
# -1.0 1.1367273386013248e+17 QLearner(pos=3.7e+16, bullets=-5.8e+16, angle=-4.1e+16, courage=1.0)
# QLearner(pos=8e+16, bullets=-1.3e+17, angle=-8.9e+16, courage=1.0)
# Game 2
# 2it [00:00,  2.72it/s]
# 0.0011790184577738603 2.5965151021785408e+17 QLearner(pos=8e+16, bullets=-1.3e+17, angle=-8.9e+16, courage=1.0)
# -0.0011790184577738603 -2.5965151021785408e+17 QLearner(pos=6.6e+16, bullets=-1.3e+17, angle=-3.4e+16, courage=1.0)
# 0.0013100205086376223 -2.1405825411801136e+16 QLearner(pos=5.1e+16, bullets=-1.3e+17, angle=2.2e+16, courage=1.0)
# -0.0013100205086376223 2.1405825411801136e+16 QLearner(pos=5.3e+16, bullets=-1.3e+17, angle=1.8e+16, courage=1.0)
# 0.0014555783429306916 2101525633431976.0 QLearner(pos=5.4e+16, bullets=-1.3e+17, angle=1.3e+16, courage=1.0)
# -0.0014555783429306916 -2101525633431976.0 QLearner(pos=5.4e+16, bullets=-1.3e+17, angle=1.4e+16, courage=1.0)
# 0.0016173092699229906 416453173726836.0 QLearner(pos=5.4e+16, bullets=-1.3e+17, angle=1.4e+16, courage=1.0)
# -0.0016173092699229906 -416453173726836.0 QLearner(pos=5.4e+16, bullets=-1.3e+17, angle=1.4e+16, courage=1.0)
# 0.001797010299914434 705756370935044.0 QLearner(pos=5.4e+16, bullets=-1.3e+17, angle=1.4e+16, courage=1.0)
# -0.001797010299914434 -705756370935044.0 QLearner(pos=5.3e+16, bullets=-1.3e+17, angle=1.4e+16, courage=1.0)
# 0.0019966781110160375 868052112497128.0 QLearner(pos=5.3e+16, bullets=-1.3e+17, angle=1.4e+16, courage=1.0)
# -0.0019966781110160375 -868052112497128.0 QLearner(pos=5.3e+16, bullets=-1.3e+17, angle=1.5e+16, courage=1.0)
# 0.002218531234462264 1103311263227816.0 QLearner(pos=5.3e+16, bullets=-1.3e+17, angle=1.5e+16, courage=1.0)
# -0.002218531234462264 -1103311263227816.0 QLearner(pos=5.3e+16, bullets=-1.3e+17, angle=1.5e+16, courage=1.0)
# 0.002465034704958071 1241858634645424.0 QLearner(pos=5.3e+16, bullets=-1.3e+17, angle=1.5e+16, courage=1.0)
# -0.002465034704958071 -1241858634645424.0 QLearner(pos=5.3e+16, bullets=-1.3e+17, angle=1.6e+16, courage=1.0)
# 0.002738927449953412 1445760127115928.0 QLearner(pos=5.3e+16, bullets=-1.3e+17, angle=1.6e+16, courage=1.0)
# -0.002738927449953412 -1445760127115928.0 QLearner(pos=5.3e+16, bullets=-1.3e+17, angle=1.6e+16, courage=1.0)
# 0.0030432527221704577 1628390834154136.0 QLearner(pos=5.3e+16, bullets=-1.3e+17, angle=1.6e+16, courage=1.0)
# -0.0030432527221704577 -1628390834154136.0 QLearner(pos=5.3e+16, bullets=-1.3e+17, angle=1.7e+16, courage=1.0)
# 0.0033813919135227306 1802924275879928.0 QLearner(pos=5.3e+16, bullets=-1.3e+17, angle=1.7e+16, courage=1.0)
# -0.0033813919135227306 -1802924275879928.0 QLearner(pos=5.3e+16, bullets=-1.3e+17, angle=1.7e+16, courage=1.0)
# 0.0037571021261363674 1975232628643992.0 QLearner(pos=5.2e+16, bullets=-1.3e+17, angle=1.8e+16, courage=1.0)
# -0.0037571021261363674 -1975232628643992.0 QLearner(pos=5.2e+16, bullets=-1.3e+17, angle=1.8e+16, courage=1.0)
# 0.004174557917929297 2148650245806976.0 QLearner(pos=5.2e+16, bullets=-1.3e+17, angle=1.8e+16, courage=1.0)
# -0.004174557917929297 -2148650245806976.0 QLearner(pos=5.2e+16, bullets=-1.3e+17, angle=1.9e+16, courage=1.0)
# 0.004638397686588108 2284378908329520.0 QLearner(pos=5.2e+16, bullets=-1.3e+17, angle=1.9e+16, courage=1.0)
# -0.004638397686588108 -2284378908329520.0 QLearner(pos=5.2e+16, bullets=-1.3e+17, angle=2e+16, courage=1.0)
# 0.00515377520732012 2411061022838120.0 QLearner(pos=5.2e+16, bullets=-1.3e+17, angle=2e+16, courage=1.0)
# -0.00515377520732012 -2411061022838120.0 QLearner(pos=5.1e+16, bullets=-1.3e+17, angle=2.1e+16, courage=1.0)
# 0.005726416897022355 2536421990809040.0 QLearner(pos=5.1e+16, bullets=-1.3e+17, angle=2.1e+16, courage=1.0)
# -0.005726416897022355 -2536421990809040.0 QLearner(pos=5.1e+16, bullets=-1.3e+17, angle=2.1e+16, courage=1.0)
# 0.00636268544113595 1.6540169224965248e+16 QLearner(pos=5.1e+16, bullets=-1.3e+17, angle=2.2e+16, courage=1.0)
# -0.00636268544113595 -1.6540169224965248e+16 QLearner(pos=4.9e+16, bullets=-1.3e+17, angle=2.5e+16, courage=1.0)
# 0.007069650490151055 3.0654682297214336e+16 QLearner(pos=4.8e+16, bullets=-1.3e+17, angle=2.8e+16, courage=1.0)
# -0.007069650490151055 -3.0654682297214336e+16 QLearner(pos=4.6e+16, bullets=-1.2e+17, angle=3.3e+16, courage=1.0)
# 0.00785516721127895 3.070070079686643e+16 QLearner(pos=4.3e+16, bullets=-1.2e+17, angle=3.8e+16, courage=1.0)
# -0.00785516721127895 -3.070070079686643e+16 QLearner(pos=4e+16, bullets=-1.2e+17, angle=4.3e+16, courage=1.0)
# 0.008727963568087723 2.7415219435562624e+16 QLearner(pos=3.8e+16, bullets=-1.2e+17, angle=4.9e+16, courage=1.0)
# -0.008727963568087723 -2.7415219435562624e+16 QLearner(pos=3.5e+16, bullets=-1.2e+17, angle=5.3e+16, courage=1.0)
# 0.009697737297875247 2.381888062055552e+16 QLearner(pos=3.3e+16, bullets=-1.2e+17, angle=5.8e+16, courage=1.0)
# -0.009697737297875247 -2.381888062055552e+16 QLearner(pos=3.1e+16, bullets=-1.2e+17, angle=6.2e+16, courage=1.0)
# 0.01077526366430583 2.0214323065182336e+16 QLearner(pos=2.9e+16, bullets=-1.1e+17, angle=6.6e+16, courage=1.0)
# -0.01077526366430583 -2.0214323065182336e+16 QLearner(pos=2.7e+16, bullets=-1.1e+17, angle=6.9e+16, courage=1.0)
# 0.011972515182562033 8079865013525760.0 QLearner(pos=2.5e+16, bullets=-1.1e+17, angle=7.2e+16, courage=1.0)
# -0.011972515182562033 -8079865013525760.0 QLearner(pos=2.4e+16, bullets=-1.1e+17, angle=7.3e+16, courage=1.0)
# 0.013302794647291146 4295001269471872.0 QLearner(pos=2.3e+16, bullets=-1.1e+17, angle=7.5e+16, courage=1.0)
# -0.013302794647291146 -4295001269471872.0 QLearner(pos=2.3e+16, bullets=-1.1e+17, angle=7.6e+16, courage=1.0)
# 0.014780882941434608 -7326371480846464.0 QLearner(pos=2.3e+16, bullets=-1.1e+17, angle=7.6e+16, courage=1.0)
# -0.014780882941434608 7326371480846464.0 QLearner(pos=2.3e+16, bullets=-1.1e+17, angle=7.5e+16, courage=1.0)
# 0.016423203268260675 5500430190443008.0 QLearner(pos=2.4e+16, bullets=-1.1e+17, angle=7.3e+16, courage=1.0)
# -0.016423203268260675 -5500430190443008.0 QLearner(pos=2.4e+16, bullets=-1.1e+17, angle=7.5e+16, courage=1.0)
# 0.01824800363140075 -1805437389222016.0 QLearner(pos=2.3e+16, bullets=-1.1e+17, angle=7.6e+16, courage=1.0)
# -0.01824800363140075 1805437389222016.0 QLearner(pos=2.3e+16, bullets=-1.1e+17, angle=7.5e+16, courage=1.0)
# 0.020275559590445275 5624836899627520.0 QLearner(pos=2.3e+16, bullets=-1.1e+17, angle=7.5e+16, courage=1.0)
# -0.020275559590445275 -5624836899627520.0 QLearner(pos=2.3e+16, bullets=-1.1e+17, angle=7.6e+16, courage=1.0)
# 0.022528399544939195 4139520546388736.0 QLearner(pos=2.2e+16, bullets=-1.1e+17, angle=7.7e+16, courage=1.0)
# -0.022528399544939195 -4139520546388736.0 QLearner(pos=2.2e+16, bullets=-1.1e+17, angle=7.8e+16, courage=1.0)
# 0.025031555049932437 1.4381314657172352e+16 QLearner(pos=2.1e+16, bullets=-1.1e+17, angle=7.9e+16, courage=1.0)
# -0.025031555049932437 -1.4381314657172352e+16 QLearner(pos=2e+16, bullets=-1e+17, angle=8.2e+16, courage=1.0)
# 0.027812838944369374 -2.9515446183750784e+16 QLearner(pos=1.8e+16, bullets=-1e+17, angle=8.6e+16, courage=1.0)
# -0.027812838944369374 2.9515446183750784e+16 QLearner(pos=2.1e+16, bullets=-1.1e+17, angle=8e+16, courage=1.0)
# 0.030903154382632636 2.738363628273037e+16 QLearner(pos=2.5e+16, bullets=-1.1e+17, angle=7.3e+16, courage=1.0)
# -0.030903154382632636 -2.738363628273037e+16 QLearner(pos=2.2e+16, bullets=-1.1e+17, angle=7.9e+16, courage=1.0)
# 0.03433683820292515 -4.961221116569446e+16 QLearner(pos=1.9e+16, bullets=-1e+17, angle=8.5e+16, courage=1.0)
# -0.03433683820292515 4.961221116569446e+16 QLearner(pos=2.4e+16, bullets=-1.1e+17, angle=7.5e+16, courage=1.0)
# 0.038152042447694615 5.00479169413655e+16 QLearner(pos=3e+16, bullets=-1.1e+17, angle=6.4e+16, courage=1.0)
# -0.038152042447694615 -5.00479169413655e+16 QLearner(pos=2.4e+16, bullets=-1.1e+17, angle=7.5e+16, courage=1.0)
# 0.04239115827521624 -6353718153532928.0 QLearner(pos=1.8e+16, bullets=-9.8e+16, angle=8.6e+16, courage=1.0)
# -0.04239115827521624 6353718153532928.0 QLearner(pos=1.9e+16, bullets=-9.9e+16, angle=8.5e+16, courage=1.0)
# 0.047101286972462485 3.5482457971003264e+16 QLearner(pos=2e+16, bullets=-1e+17, angle=8.3e+16, courage=1.0)
# -0.047101286972462485 -3.5482457971003264e+16 QLearner(pos=1.6e+16, bullets=-9.4e+16, angle=9.1e+16, courage=1.0)
# 0.05233476330273609 4998967239835264.0 QLearner(pos=1.2e+16, bullets=-8.7e+16, angle=9.9e+16, courage=1.0)
# -0.05233476330273609 -4998967239835264.0 QLearner(pos=1.1e+16, bullets=-8.6e+16, angle=1e+17, courage=1.0)
# 0.058149737003040096 2.509862550276429e+16 QLearner(pos=1.1e+16, bullets=-8.5e+16, angle=1e+17, courage=1.0)
# -0.058149737003040096 -2.509862550276429e+16 QLearner(pos=7.6e+15, bullets=-7.8e+16, angle=1.1e+17, courage=1.0)
# 0.06461081889226677 -6.771988855741069e+16 QLearner(pos=4.6e+15, bullets=-7.1e+16, angle=1.1e+17, courage=1.0)
# -0.06461081889226677 6.771988855741069e+16 QLearner(pos=1.3e+16, bullets=-8.8e+16, angle=9.7e+16, courage=1.0)
# 0.0717897987691853 1.2886355169320358e+17 QLearner(pos=2.1e+16, bullets=-1e+17, angle=8.2e+16, courage=1.0)
# -0.0717897987691853 -1.2886355169320358e+17 QLearner(pos=5.2e+15, bullets=-7e+16, angle=1.1e+17, courage=1.0)
# 0.07976644307687256 -2.56869590136709e+17 QLearner(pos=-1e+16, bullets=-3.5e+16, angle=1.4e+17, courage=1.0)
# -0.07976644307687256 2.56869590136709e+17 QLearner(pos=2.1e+16, bullets=-1.1e+17, angle=8.3e+16, courage=1.0)
# 0.08862938119652507 6.314969363519578e+17 QLearner(pos=5.2e+16, bullets=-1.8e+17, angle=2.4e+16, courage=1.0)
# -0.08862938119652507 -6.314969363519578e+17 QLearner(pos=-2.5e+16, bullets=1.1e+16, angle=1.7e+17, courage=1.0)
# 0.09847709021836118 -1.672201908283287e+18 QLearner(pos=-1e+17, bullets=2e+17, angle=3.1e+17, courage=1.0)
# -0.09847709021836118 1.672201908283287e+18 QLearner(pos=1e+17, bullets=-3.5e+17, angle=-7e+16, courage=1.0)
# 0.10941898913151242 4.979295022650991e+18 QLearner(pos=3.1e+17, bullets=-9e+17, angle=-4.5e+17, courage=1.0)
# -0.10941898913151242 -4.979295022650991e+18 QLearner(pos=-3.1e+17, bullets=8.1e+17, angle=6.9e+17, courage=1.0)
# 0.12157665459056935 -1.6066141216458437e+19 QLearner(pos=-9.4e+17, bullets=2.5e+18, angle=1.8e+18, courage=1.0)
# -0.12157665459056935 1.6066141216458437e+19 QLearner(pos=1.1e+18, bullets=-3.2e+18, angle=-2e+18, courage=1.0)
# 0.13508517176729928 5.588296529481107e+19 QLearner(pos=3.2e+18, bullets=-9e+18, angle=-5.9e+18, courage=1.0)
# -0.13508517176729928 -5.588296529481107e+19 QLearner(pos=-4.1e+18, bullets=1.1e+19, angle=7.5e+18, courage=1.0)
# 0.15009463529699918 -2.0207249805648285e+20 QLearner(pos=-1.1e+19, bullets=3.2e+19, angle=2.1e+19, courage=1.0)
# -0.15009463529699918 2.0207249805648285e+20 QLearner(pos=1.5e+19, bullets=-4.4e+19, angle=-2.8e+19, courage=1.0)
# 0.16677181699666577 7.659167624860535e+20 QLearner(pos=4.2e+19, bullets=-1.2e+20, angle=-7.6e+19, courage=1.0)
# -0.16677181699666577 -7.659167624860535e+20 QLearner(pos=-6e+19, bullets=1.7e+20, angle=1.1e+20, courage=1.0)
# 0.18530201888518416 -3.10530227355082e+21 QLearner(pos=-1.6e+20, bullets=4.7e+20, angle=2.9e+20, courage=1.0)
# -0.18530201888518416 3.10530227355082e+21 QLearner(pos=2.6e+20, bullets=-7.9e+20, angle=-4.5e+20, courage=1.0)
# 0.20589113209464907 1.3983630746729446e+22 QLearner(pos=6.8e+20, bullets=-2.1e+21, angle=-1.2e+21, courage=1.0)
# -0.20589113209464907 -1.3983630746729446e+22 QLearner(pos=-1.3e+21, bullets=3.9e+21, angle=2.3e+21, courage=1.0)
# 0.2287679245496101 -7.1347515771520624e+22 QLearner(pos=-3.2e+21, bullets=9.9e+21, angle=5.8e+21, courage=1.0)
# -0.2287679245496101 7.1347515771520624e+22 QLearner(pos=6.9e+21, bullets=-2.3e+22, angle=-1.2e+22, courage=1.0)
# 0.2541865828329001 4.068473602499668e+23 QLearner(pos=1.7e+22, bullets=-5.6e+22, angle=-3e+22, courage=1.0)
# -0.2541865828329001 -4.068473602499668e+23 QLearner(pos=-4.2e+22, bullets=1.4e+23, angle=7.2e+22, courage=1.0)
# 0.2824295364810001 -2.4437861707289934e+24 QLearner(pos=-1e+23, bullets=3.3e+23, angle=1.7e+23, courage=1.0)
# -0.2824295364810001 2.4437861707289934e+24 QLearner(pos=2.6e+23, bullets=-8.6e+23, angle=-4.4e+23, courage=1.0)
# 0.31381059609000006 1.5218579747649298e+25 QLearner(pos=6.2e+23, bullets=-2.1e+24, angle=-1.1e+24, courage=1.0)
# -0.31381059609000006 -1.5218579747649298e+25 QLearner(pos=-1.7e+24, bullets=5.6e+24, angle=2.6e+24, courage=1.0)
# 0.3486784401000001 -9.737102564154712e+25 QLearner(pos=-4e+24, bullets=1.3e+25, angle=6.3e+24, courage=1.0)
# -0.3486784401000001 9.737102564154712e+25 QLearner(pos=1.1e+25, bullets=-3.7e+25, angle=-1.6e+25, courage=1.0)
# 0.3874204890000001 6.512569213457381e+26 QLearner(pos=2.6e+25, bullets=-8.7e+25, angle=-3.8e+25, courage=1.0)
# -0.3874204890000001 -6.512569213457381e+26 QLearner(pos=-7.9e+25, bullets=2.6e+26, angle=1e+26, courage=1.0)
# 0.4304672100000001 -3.8856613155939527e+27 QLearner(pos=-1.8e+26, bullets=6.1e+26, angle=2.4e+26, courage=1.0)
# -0.4304672100000001 3.8856613155939527e+27 QLearner(pos=4.6e+26, bullets=-1.1e+27, angle=-6.4e+26, courage=1.0)
# 0.4782969000000001 1.9237739903424286e+28 QLearner(pos=1.1e+27, bullets=-2.8e+27, angle=-1.5e+27, courage=1.0)
# -0.4782969000000001 -1.9237739903424286e+28 QLearner(pos=-2.2e+27, bullets=5.5e+27, angle=3.1e+27, courage=1.0)
# 0.531441 -9.089820778472651e+28 QLearner(pos=-5.5e+27, bullets=1.4e+28, angle=7.7e+27, courage=1.0)
# -0.531441 9.089820778472651e+28 QLearner(pos=1.1e+28, bullets=-2.2e+28, angle=-1.5e+28, courage=1.0)
# 0.5904900000000001 4.6527761873017714e+29 QLearner(pos=2.7e+28, bullets=-5.7e+28, angle=-3.8e+28, courage=1.0)
# -0.5904900000000001 -4.6527761873017714e+29 QLearner(pos=-6.1e+28, bullets=1.3e+29, angle=1.4e+29, courage=1.0)
# 0.6561 -3.129022873361465e+30 QLearner(pos=-1.5e+29, bullets=3.1e+29, angle=3.2e+29, courage=1.0)
# -0.6561 3.129022873361465e+30 QLearner(pos=5e+29, bullets=-1e+30, angle=-8.6e+29, courage=1.0)
# 0.7290000000000001 2.3419274034678637e+31 QLearner(pos=1.1e+30, bullets=-2.4e+30, angle=-2e+30, courage=1.0)
# -0.7290000000000001 -2.3419274034678637e+31 QLearner(pos=-4.2e+30, bullets=8.4e+30, angle=7.1e+30, courage=1.0)
# 0.81 -1.9636691813814304e+32 QLearner(pos=-9.6e+30, bullets=1.9e+31, angle=1.6e+31, courage=1.0)
# -0.81 1.9636691813814304e+32 QLearner(pos=4e+31, bullets=-7.5e+31, angle=-6e+31, courage=1.0)
# 0.9 1.821147785904134e+33 QLearner(pos=9.1e+31, bullets=-1.7e+32, angle=-1.4e+32, courage=1.0)
# -0.9 -1.821147785904134e+33 QLearner(pos=-4.4e+32, bullets=7.6e+32, angle=5.7e+32, courage=1.0)
# 1.0 -1.9147547617933958e+34 QLearner(pos=-9.7e+32, bullets=1.7e+33, angle=1.3e+33, courage=1.0)
# -1.0 1.9147547617933958e+34 QLearner(pos=5.6e+33, bullets=-8.7e+33, angle=-6.2e+33, courage=1.0)
# QLearner(pos=1.2e+34, bullets=-1.9e+34, angle=-1.4e+34, courage=1.0)
# Game 3
# 3it [00:01,  2.41it/s]
# 0.00017696434542799797 3.1098744618389693e+34 QLearner(pos=1.2e+34, bullets=-1.9e+34, angle=-1.4e+34, courage=1.0)
# -0.00017696434542799797 -3.1098744618389693e+34 QLearner(pos=1.2e+34, bullets=-1.9e+34, angle=-7.9e+33, courage=1.0)
# 0.00019662705047555332 5.915693790188074e+33 QLearner(pos=1.2e+34, bullets=-1.9e+34, angle=-2.2e+33, courage=1.0)
# -0.00019662705047555332 -5.915693790188074e+33 QLearner(pos=1.2e+34, bullets=-1.9e+34, angle=-1.1e+33, courage=1.0)
# 0.00021847450052839255 1.2372150654369833e+33 QLearner(pos=1.2e+34, bullets=-1.9e+34, angle=-5e+30, courage=1.0)
# -0.00021847450052839255 -1.2372150654369833e+33 QLearner(pos=1.2e+34, bullets=-1.9e+34, angle=2.2e+32, courage=1.0)
# 0.0002427494450315473 3.613531096881024e+32 QLearner(pos=1.2e+34, bullets=-1.9e+34, angle=4.4e+32, courage=1.0)
# -0.0002427494450315473 -3.613531096881024e+32 QLearner(pos=1.2e+34, bullets=-1.9e+34, angle=5.1e+32, courage=1.0)
# 0.0002697216055906081 2.1233143127630077e+32 QLearner(pos=1.2e+34, bullets=-1.9e+34, angle=5.7e+32, courage=1.0)
# -0.0002697216055906081 -2.1233143127630077e+32 QLearner(pos=1.2e+34, bullets=-1.9e+34, angle=6.1e+32, courage=1.0)
# 0.0002996906728784534 2.2855103687577395e+32 QLearner(pos=1.2e+34, bullets=-1.9e+34, angle=6.4e+32, courage=1.0)
# -0.0002996906728784534 -2.2855103687577395e+32 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=6.8e+32, courage=1.0)
# 0.0003329896365316149 2.769793634274048e+32 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=7.2e+32, courage=1.0)
# -0.0003329896365316149 -2.769793634274048e+32 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=7.7e+32, courage=1.0)
# 0.00036998848503512764 3.348928216361425e+32 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=8.1e+32, courage=1.0)
# -0.00036998848503512764 -3.348928216361425e+32 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=8.6e+32, courage=1.0)
# 0.0004110983167056974 4.1786488162293164e+32 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=9.1e+32, courage=1.0)
# -0.0004110983167056974 -4.1786488162293164e+32 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=9.8e+32, courage=1.0)
# 0.00045677590745077487 5.0917724927344806e+32 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=1e+33, courage=1.0)
# -0.00045677590745077487 -5.0917724927344806e+32 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=1.1e+33, courage=1.0)
# 0.0005075287860564165 6.073155042818671e+32 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=1.2e+33, courage=1.0)
# -0.0005075287860564165 -6.073155042818671e+32 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=1.3e+33, courage=1.0)
# 0.0005639208733960184 7.230319040977406e+32 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=1.3e+33, courage=1.0)
# -0.0005639208733960184 -7.230319040977406e+32 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=1.4e+33, courage=1.0)
# 0.0006265787482177981 8.540851883851318e+32 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=1.5e+33, courage=1.0)
# -0.0006265787482177981 -8.540851883851318e+32 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=1.6e+33, courage=1.0)
# 0.0006961986091308868 9.847058126478656e+32 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=1.7e+33, courage=1.0)
# -0.0006961986091308868 -9.847058126478656e+32 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=1.8e+33, courage=1.0)
# 0.0007735540101454297 1.1121862685927488e+33 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=1.9e+33, courage=1.0)
# -0.0007735540101454297 -1.1121862685927488e+33 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=2e+33, courage=1.0)
# 0.0008595044557171441 1.2367297209936492e+33 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=2.2e+33, courage=1.0)
# -0.0008595044557171441 -1.2367297209936492e+33 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=2.3e+33, courage=1.0)
# 0.0009550049507968268 4.9743556706852717e+33 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=2.4e+33, courage=1.0)
# -0.0009550049507968268 -4.9743556706852717e+33 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=2.8e+33, courage=1.0)
# 0.001061116611996474 9.521323532000557e+33 QLearner(pos=1.1e+34, bullets=-1.9e+34, angle=3.3e+33, courage=1.0)
# -0.001061116611996474 -9.521323532000557e+33 QLearner(pos=1.1e+34, bullets=-1.8e+34, angle=4.3e+33, courage=1.0)
# 0.0011790184577738603 1.0433407163100033e+34 QLearner(pos=1e+34, bullets=-1.8e+34, angle=5.3e+33, courage=1.0)
# -0.0011790184577738603 -1.0433407163100033e+34 QLearner(pos=1e+34, bullets=-1.7e+34, angle=6.5e+33, courage=1.0)
# 0.0013100205086376223 7.447616267931171e+33 QLearner(pos=9.6e+33, bullets=-1.7e+34, angle=7.6e+33, courage=1.0)
# -0.0013100205086376223 -7.447616267931171e+33 QLearner(pos=9.4e+33, bullets=-1.6e+34, angle=8.6e+33, courage=1.0)
# 0.0014555783429306916 3.0119916700634176e+33 QLearner(pos=9.1e+33, bullets=-1.6e+34, angle=9.6e+33, courage=1.0)
# -0.0014555783429306916 -3.0119916700634176e+33 QLearner(pos=9e+33, bullets=-1.5e+34, angle=1e+34, courage=1.0)
# 0.0016173092699229906 1.1023264860662128e+33 QLearner(pos=8.9e+33, bullets=-1.5e+34, angle=1e+34, courage=1.0)
# -0.0016173092699229906 -1.1023264860662128e+33 QLearner(pos=8.8e+33, bullets=-1.5e+34, angle=1.1e+34, courage=1.0)
# 0.001797010299914434 -1.4812199121361668e+33 QLearner(pos=8.8e+33, bullets=-1.5e+34, angle=1.1e+34, courage=1.0)
# -0.001797010299914434 1.4812199121361668e+33 QLearner(pos=8.9e+33, bullets=-1.5e+34, angle=1.1e+34, courage=1.0)
# 0.0019966781110160375 -6.445694964364807e+32 QLearner(pos=8.9e+33, bullets=-1.5e+34, angle=1e+34, courage=1.0)
# -0.0019966781110160375 6.445694964364807e+32 QLearner(pos=9e+33, bullets=-1.5e+34, angle=1e+34, courage=1.0)
# 0.002218531234462264 -2.115307653773939e+33 QLearner(pos=9e+33, bullets=-1.5e+34, angle=1e+34, courage=1.0)
# -0.002218531234462264 2.115307653773939e+33 QLearner(pos=9.1e+33, bullets=-1.6e+34, angle=9.6e+33, courage=1.0)
# 0.002465034704958071 -4.0028158704576135e+32 QLearner(pos=9.2e+33, bullets=-1.6e+34, angle=9.2e+33, courage=1.0)
# -0.002465034704958071 4.0028158704576135e+32 QLearner(pos=9.2e+33, bullets=-1.6e+34, angle=9.1e+33, courage=1.0)
# 0.002738927449953412 -2.085371498287206e+33 QLearner(pos=9.2e+33, bullets=-1.6e+34, angle=9e+33, courage=1.0)
# -0.002738927449953412 2.085371498287206e+33 QLearner(pos=9.3e+33, bullets=-1.6e+34, angle=8.5e+33, courage=1.0)
# 0.0030432527221704577 9.067458552421816e+31 QLearner(pos=9.4e+33, bullets=-1.6e+34, angle=8e+33, courage=1.0)
# -0.0030432527221704577 -9.067458552421816e+31 QLearner(pos=9.4e+33, bullets=-1.6e+34, angle=8.1e+33, courage=1.0)
# 0.0033813919135227306 -1.2551159019436973e+33 QLearner(pos=9.4e+33, bullets=-1.6e+34, angle=8.1e+33, courage=1.0)
# -0.0033813919135227306 1.2551159019436973e+33 QLearner(pos=9.5e+33, bullets=-1.6e+34, angle=7.8e+33, courage=1.0)
# 0.0037571021261363674 -1.6777721782998182e+32 QLearner(pos=9.5e+33, bullets=-1.6e+34, angle=7.4e+33, courage=1.0)
# -0.0037571021261363674 1.6777721782998182e+32 QLearner(pos=9.5e+33, bullets=-1.6e+34, angle=7.4e+33, courage=1.0)
# 0.004174557917929297 -1.0541586195437924e+33 QLearner(pos=9.6e+33, bullets=-1.6e+34, angle=7.4e+33, courage=1.0)
# -0.004174557917929297 1.0541586195437924e+33 QLearner(pos=9.6e+33, bullets=-1.7e+34, angle=7.1e+33, courage=1.0)
# 0.004638397686588108 1.6275118174455897e+33 QLearner(pos=9.7e+33, bullets=-1.7e+34, angle=6.8e+33, courage=1.0)
# -0.004638397686588108 -1.6275118174455897e+33 QLearner(pos=9.6e+33, bullets=-1.6e+34, angle=7.2e+33, courage=1.0)
# 0.00515377520732012 -7.978020473888735e+32 QLearner(pos=9.5e+33, bullets=-1.6e+34, angle=7.6e+33, courage=1.0)
# -0.00515377520732012 7.978020473888735e+32 QLearner(pos=9.5e+33, bullets=-1.6e+34, angle=7.4e+33, courage=1.0)
# 0.005726416897022355 7.329789850245268e+33 QLearner(pos=9.6e+33, bullets=-1.6e+34, angle=7.2e+33, courage=1.0)
# -0.005726416897022355 -7.329789850245268e+33 QLearner(pos=9.1e+33, bullets=-1.6e+34, angle=9e+33, courage=1.0)
# 0.00636268544113595 -6.53706299523671e+33 QLearner(pos=8.6e+33, bullets=-1.5e+34, angle=1.1e+34, courage=1.0)
# -0.00636268544113595 6.53706299523671e+33 QLearner(pos=9.1e+33, bullets=-1.6e+34, angle=9.3e+33, courage=1.0)
# 0.007069650490151055 1.0754425465409102e+34 QLearner(pos=9.5e+33, bullets=-1.6e+34, angle=7.8e+33, courage=1.0)
# -0.007069650490151055 -1.0754425465409102e+34 QLearner(pos=8.8e+33, bullets=-1.5e+34, angle=1e+34, courage=1.0)
# 0.00785516721127895 -3.165374271854158e+32 QLearner(pos=8e+33, bullets=-1.4e+34, angle=1.2e+34, courage=1.0)
# -0.00785516721127895 3.165374271854158e+32 QLearner(pos=8e+33, bullets=-1.4e+34, angle=1.2e+34, courage=1.0)
# 0.008727963568087723 1.56793848806951e+32 QLearner(pos=8e+33, bullets=-1.4e+34, angle=1.2e+34, courage=1.0)
# -0.008727963568087723 -1.56793848806951e+32 QLearner(pos=8e+33, bullets=-1.4e+34, angle=1.2e+34, courage=1.0)
# 0.009697737297875247 2.27707026034001e+34 QLearner(pos=8e+33, bullets=-1.4e+34, angle=1.2e+34, courage=1.0)
# -0.009697737297875247 -2.27707026034001e+34 QLearner(pos=6.3e+33, bullets=-7.5e+33, angle=1.7e+34, courage=1.0)
# 0.01077526366430583 -3.5802720114884054e+34 QLearner(pos=4.5e+33, bullets=-1.4e+33, angle=2.1e+34, courage=1.0)
# -0.01077526366430583 3.5802720114884054e+34 QLearner(pos=7.3e+33, bullets=-1.2e+34, angle=1.5e+34, courage=1.0)
# 0.011972515182562033 7.557794464024226e+34 QLearner(pos=1e+34, bullets=-2.2e+34, angle=8.2e+33, courage=1.0)
# -0.011972515182562033 -7.557794464024226e+34 QLearner(pos=4.2e+33, bullets=1.4e+33, angle=2.1e+34, courage=1.0)
# 0.013302794647291146 -1.6466133197923977e+35 QLearner(pos=-1.7e+33, bullets=2.5e+34, angle=3.4e+34, courage=1.0)
# -0.013302794647291146 1.6466133197923977e+35 QLearner(pos=1.1e+34, bullets=-3e+34, angle=7.7e+33, courage=1.0)
# 0.014780882941434608 4.146924945649258e+35 QLearner(pos=2.4e+34, bullets=-8.5e+34, angle=-1.8e+34, courage=1.0)
# -0.014780882941434608 -4.146924945649258e+35 QLearner(pos=-8.5e+33, bullets=6.2e+34, angle=4.3e+34, courage=1.0)
# 0.016423203268260675 -1.077906959706053e+36 QLearner(pos=-4.1e+34, bullets=2.1e+35, angle=1e+35, courage=1.0)
# -0.016423203268260675 1.077906959706053e+36 QLearner(pos=4.4e+34, bullets=-1.6e+35, angle=-5.5e+34, courage=1.0)
# 0.01824800363140075 2.4726404628203243e+36 QLearner(pos=1.3e+35, bullets=-5.3e+35, angle=-2.1e+35, courage=1.0)
# -0.01824800363140075 -2.4726404628203243e+36 QLearner(pos=-6.7e+34, bullets=2.4e+35, angle=1.5e+35, courage=1.0)
# 0.020275559590445275 -5.1928554732400747e+36 QLearner(pos=-2.6e+35, bullets=1e+36, angle=5.1e+35, courage=1.0)
# -0.020275559590445275 5.1928554732400747e+36 QLearner(pos=1.5e+35, bullets=-7.1e+35, angle=-2.5e+35, courage=1.0)
# 0.022528399544939195 1.2552126561188976e+37 QLearner(pos=5.6e+35, bullets=-2.4e+36, angle=-1e+36, courage=1.0)
# -0.022528399544939195 -1.2552126561188976e+37 QLearner(pos=-4.4e+35, bullets=2e+36, angle=8.3e+35, courage=1.0)
# 0.025031555049932437 -3.4387734507992926e+37 QLearner(pos=-1.4e+36, bullets=6.4e+36, angle=2.7e+36, courage=1.0)
# -0.025031555049932437 3.4387734507992926e+37 QLearner(pos=1.3e+36, bullets=-6.3e+36, angle=-2.4e+36, courage=1.0)
# 0.027812838944369374 1.0169260650919705e+38 QLearner(pos=4.1e+36, bullets=-1.9e+37, angle=-7.4e+36, courage=1.0)
# -0.027812838944369374 -1.0169260650919705e+38 QLearner(pos=-4.1e+36, bullets=1.9e+37, angle=6.5e+36, courage=1.0)
# 0.030903154382632636 -3.193224852040746e+38 QLearner(pos=-1.2e+37, bullets=5.7e+37, angle=2e+37, courage=1.0)
# -0.030903154382632636 3.193224852040746e+38 QLearner(pos=1.4e+37, bullets=-7e+37, angle=-2.3e+37, courage=1.0)
# 0.03433683820292515 1.169397959705526e+39 QLearner(pos=4e+37, bullets=-2e+38, angle=-6.7e+37, courage=1.0)
# -0.03433683820292515 -1.169397959705526e+39 QLearner(pos=-5.6e+37, bullets=3.1e+38, angle=9.3e+37, courage=1.0)
# 0.038152042447694615 -5.030006184485602e+39 QLearner(pos=-1.5e+38, bullets=8.1e+38, angle=2.5e+38, courage=1.0)
# -0.038152042447694615 5.030006184485602e+39 QLearner(pos=2.6e+38, bullets=-1.5e+39, angle=-4.4e+38, courage=1.0)
# 0.04239115827521624 2.487812130339188e+40 QLearner(pos=6.8e+38, bullets=-3.8e+39, angle=-1.1e+39, courage=1.0)
# -0.04239115827521624 -2.487812130339188e+40 QLearner(pos=-1.4e+39, bullets=8.4e+39, angle=2e+39, courage=1.0)
# 0.047101286972462485 -1.428745970943256e+41 QLearner(pos=-3.5e+39, bullets=2.1e+40, angle=5.2e+39, courage=1.0)
# -0.047101286972462485 1.428745970943256e+41 QLearner(pos=8.6e+39, bullets=-5.6e+40, angle=-1.3e+40, courage=1.0)
# 0.05233476330273609 9.745902887668389e+41 QLearner(pos=2.1e+40, bullets=-1.3e+41, angle=-3.1e+40, courage=1.0)
# -0.05233476330273609 -9.745902887668389e+41 QLearner(pos=-6.3e+40, bullets=4.3e+41, angle=9.2e+40, courage=1.0)
# 0.058149737003040096 -7.546225867617928e+42 QLearner(pos=-1.5e+41, bullets=9.9e+41, angle=2.2e+41, courage=1.0)
# -0.058149737003040096 7.546225867617928e+42 QLearner(pos=5.1e+41, bullets=-3.5e+42, angle=-7.4e+41, courage=1.0)
# 0.06461081889226677 6.414186219231053e+43 QLearner(pos=1.2e+42, bullets=-8e+42, angle=-1.7e+42, courage=1.0)
# -0.06461081889226677 -6.414186219231053e+43 QLearner(pos=-4.5e+42, bullets=3.2e+43, angle=5.7e+42, courage=1.0)
# 0.0717897987691853 -6.021501082358235e+44 QLearner(pos=-1e+43, bullets=7.3e+43, angle=1.3e+43, courage=1.0)
# -0.0717897987691853 6.021501082358235e+44 QLearner(pos=4.3e+43, bullets=-3.2e+44, angle=-5e+43, courage=1.0)
# 0.07976644307687256 6.214939390310255e+45 QLearner(pos=9.7e+43, bullets=-7.2e+44, angle=-1.1e+44, courage=1.0)
# -0.07976644307687256 -6.214939390310255e+45 QLearner(pos=-4.6e+44, bullets=3.6e+45, angle=4.8e+44, courage=1.0)
# 0.08862938119652507 -6.90411968304039e+46 QLearner(pos=-1e+45, bullets=7.9e+45, angle=1.1e+45, courage=1.0)
# -0.08862938119652507 6.90411968304039e+46 QLearner(pos=5.3e+45, bullets=-4.1e+46, angle=-4.8e+45, courage=1.0)
# 0.09847709021836118 8.064824324884243e+47 QLearner(pos=1.2e+46, bullets=-9e+46, angle=-1.1e+46, courage=1.0)
# -0.09847709021836118 -8.064824324884243e+47 QLearner(pos=-6.4e+46, bullets=5e+47, angle=4.9e+46, courage=1.0)
# 0.10941898913151242 -9.901354641828527e+48 QLearner(pos=-1.4e+47, bullets=1.1e+48, angle=1.1e+47, courage=1.0)
# -0.10941898913151242 9.901354641828527e+48 QLearner(pos=8.1e+47, bullets=-6.3e+48, angle=-5.2e+47, courage=1.0)
# 0.12157665459056935 1.2741661262755823e+50 QLearner(pos=1.8e+48, bullets=-1.4e+49, angle=-1.2e+48, courage=1.0)
# -0.12157665459056935 -1.2741661262755823e+50 QLearner(pos=-1.1e+49, bullets=8.3e+49, angle=5.7e+48, courage=1.0)
# 0.13508517176729928 -1.7082325733209516e+51 QLearner(pos=-2.3e+49, bullets=1.8e+50, angle=1.2e+49, courage=1.0)
# -0.13508517176729928 1.7082325733209516e+51 QLearner(pos=1.5e+50, bullets=-1.1e+51, angle=-6.1e+49, courage=1.0)
# 0.15009463529699918 2.4701958370315365e+52 QLearner(pos=3.2e+50, bullets=-2.5e+51, angle=-1.3e+50, courage=1.0)
# -0.15009463529699918 -2.4701958370315365e+52 QLearner(pos=-2.3e+51, bullets=1.8e+52, angle=6.7e+50, courage=1.0)
# 0.16677181699666577 -3.827465679822346e+53 QLearner(pos=-4.8e+51, bullets=3.8e+52, angle=1.5e+51, courage=1.0)
# -0.16677181699666577 3.827465679822346e+53 QLearner(pos=3.6e+52, bullets=-2.8e+53, angle=-7e+51, courage=1.0)
# 0.18530201888518416 6.002958988198233e+54 QLearner(pos=7.7e+52, bullets=-5.9e+53, angle=-1.6e+52, courage=1.0)
# -0.18530201888518416 -6.002958988198233e+54 QLearner(pos=-5.8e+53, bullets=4.4e+54, angle=1.2e+53, courage=1.0)
# 0.20589113209464907 -7.651815360594588e+55 QLearner(pos=-1.2e+54, bullets=9.4e+54, angle=2.5e+53, courage=1.0)
# -0.20589113209464907 7.651815360594588e+55 QLearner(pos=7.3e+54, bullets=-4.2e+55, angle=-6.5e+53, courage=1.0)
# 0.2287679245496101 7.507762093198611e+56 QLearner(pos=1.6e+55, bullets=-9.3e+55, angle=-1.6e+54, courage=1.0)
# -0.2287679245496101 -7.507762093198611e+56 QLearner(pos=-7e+55, bullets=4e+56, angle=-5.2e+53, courage=1.0)
# 0.2541865828329001 -7.144792685121653e+57 QLearner(pos=-1.6e+56, bullets=8.9e+56, angle=5.2e+53, courage=1.0)
# -0.2541865828329001 7.144792685121653e+57 QLearner(pos=6.9e+56, bullets=-3.7e+57, angle=-9.4e+54, courage=1.0)
# 0.2824295364810001 6.625607949545069e+58 QLearner(pos=1.5e+57, bullets=-8.3e+57, angle=-1.9e+55, courage=1.0)
# -0.2824295364810001 -6.625607949545069e+58 QLearner(pos=-6.5e+57, bullets=3.4e+58, angle=7.2e+55, courage=1.0)
# 0.31381059609000006 -6.020321597802695e+59 QLearner(pos=-1.5e+58, bullets=7.6e+58, angle=1.6e+56, courage=1.0)
# -0.31381059609000006 6.020321597802695e+59 QLearner(pos=6.2e+58, bullets=-3e+59, angle=5.6e+57, courage=1.0)
# 0.3486784401000001 4.960634912162902e+60 QLearner(pos=1.4e+59, bullets=-6.9e+59, angle=1.1e+58, courage=1.0)
# -0.3486784401000001 -4.960634912162902e+60 QLearner(pos=-5.2e+59, bullets=2.2e+60, angle=-3.4e+58, courage=1.0)
# 0.3874204890000001 -3.487966777167728e+61 QLearner(pos=-1.2e+60, bullets=5e+60, angle=-7.9e+58, courage=1.0)
# -0.3874204890000001 3.487966777167728e+61 QLearner(pos=3.7e+60, bullets=-1.4e+61, angle=2.4e+59, courage=1.0)
# 0.4304672100000001 2.4144252124418314e+62 QLearner(pos=8.5e+60, bullets=-3.3e+61, angle=5.5e+59, courage=1.0)
# -0.4304672100000001 -2.4144252124418314e+62 QLearner(pos=-2.7e+61, bullets=1.1e+62, angle=-1.6e+60, courage=1.0)
# 0.4782969000000001 -1.783471152810591e+63 QLearner(pos=-6.2e+61, bullets=2.4e+62, angle=-3.8e+60, courage=1.0)
# -0.4782969000000001 1.783471152810591e+63 QLearner(pos=2.1e+62, bullets=-7.8e+62, angle=1.2e+61, courage=1.0)
# 0.531441 1.3436668360345068e+64 QLearner(pos=4.9e+62, bullets=-1.8e+63, angle=2.8e+61, courage=1.0)
# -0.531441 -1.3436668360345068e+64 QLearner(pos=-1.7e+63, bullets=6e+63, angle=-9.3e+61, courage=1.0)
# 0.5904900000000001 -8.745484716757643e+64 QLearner(pos=-3.9e+63, bullets=1.4e+64, angle=-2.1e+62, courage=1.0)
# -0.5904900000000001 8.745484716757643e+64 QLearner(pos=1.1e+64, bullets=-2.8e+64, angle=5.8e+62, courage=1.0)
# 0.6561 4.776937887233421e+65 QLearner(pos=2.7e+64, bullets=-7e+64, angle=1.4e+63, courage=1.0)
# -0.6561 -4.776937887233421e+65 QLearner(pos=-6.4e+64, bullets=1.7e+65, angle=2e+63, courage=1.0)
# 0.7290000000000001 -2.8445398972619265e+66 QLearner(pos=-1.5e+65, bullets=4e+65, angle=2.7e+63, courage=1.0)
# -0.7290000000000001 2.8445398972619265e+66 QLearner(pos=4.3e+65, bullets=-1e+66, angle=-3.1e+64, courage=1.0)
# 0.81 1.858629335280095e+67 QLearner(pos=1e+66, bullets=-2.5e+66, angle=-6.4e+64, courage=1.0)
# -0.81 -1.858629335280095e+67 QLearner(pos=-3.2e+66, bullets=7.3e+66, angle=1.5e+65, courage=1.0)
# 0.9 -1.3890900401520898e+68 QLearner(pos=-7.3e+66, bullets=1.7e+67, angle=3.7e+65, courage=1.0)
# -0.9 1.3890900401520898e+68 QLearner(pos=2.7e+67, bullets=-6e+67, angle=-7.1e+67, courage=1.0)
# 1.0 2.1647759760908652e+69 QLearner(pos=6.2e+67, bullets=-1.4e+68, angle=-1.4e+68, courage=1.0)
# -1.0 -2.1647759760908652e+69 QLearner(pos=-5.6e+68, bullets=1.3e+69, angle=9.7e+68, courage=1.0)
# QLearner(pos=-1.2e+69, bullets=2.7e+69, angle=2.1e+69, courage=1.0)
# Game 4
# 4it [00:01,  2.20it/s]
# 0.00017696434542799797 -4.684468810385035e+69 QLearner(pos=-1.2e+69, bullets=2.7e+69, angle=2.1e+69, courage=1.0)
# -0.00017696434542799797 4.684468810385035e+69 QLearner(pos=-1.2e+69, bullets=2.7e+69, angle=1.3e+69, courage=1.0)
# 0.00019662705047555332 -1.1791753226017234e+69 QLearner(pos=-1.1e+69, bullets=2.7e+69, angle=4.9e+68, courage=1.0)
# -0.00019662705047555332 1.1791753226017234e+69 QLearner(pos=-1.1e+69, bullets=2.7e+69, angle=2.9e+68, courage=1.0)
# 0.00021847450052839255 -3.1111452810734257e+68 QLearner(pos=-1.1e+69, bullets=2.7e+69, angle=9e+67, courage=1.0)
# -0.00021847450052839255 3.1111452810734257e+68 QLearner(pos=-1.1e+69, bullets=2.7e+69, angle=3.8e+67, courage=1.0)
# 0.0002427494450315473 -9.414991415523917e+67 QLearner(pos=-1.1e+69, bullets=2.7e+69, angle=-1.4e+67, courage=1.0)
# -0.0002427494450315473 9.414991415523917e+67 QLearner(pos=-1.1e+69, bullets=2.7e+69, angle=-2.9e+67, courage=1.0)
# 0.0002697216055906081 -3.967335165195792e+67 QLearner(pos=-1.1e+69, bullets=2.7e+69, angle=-4.5e+67, courage=1.0)
# -0.0002697216055906081 3.967335165195792e+67 QLearner(pos=-1.1e+69, bullets=2.7e+69, angle=-5.1e+67, courage=1.0)
# 0.0002996906728784534 -2.898750908524536e+67 QLearner(pos=-1.1e+69, bullets=2.7e+69, angle=-5.7e+67, courage=1.0)
# ...
# -0.20589113209464907 1.4163488042861594e+180 QLearner(pos=1.5e+179, bullets=8.9e+180, angle=4.1e+179, courage=1.0)
# -0.2287679245496101 -1.6891500347494724e+180 QLearner(pos=2.1e+179, bullets=8.9e+180, angle=4.1e+179, courage=1.0)
# -0.2287679245496101 1.6891500347494724e+180 QLearner(pos=2.7e+179, bullets=8.9e+180, angle=4e+179, courage=1.0)
# -0.2541865828329001 -1.9833353607263975e+180 QLearner(pos=3.4e+179, bullets=8.9e+180, angle=3.8e+179, courage=1.0)
# -0.2541865828329001 1.9833353607263975e+180 QLearner(pos=4.1e+179, bullets=8.9e+180, angle=3.6e+179, courage=1.0)
# -0.2824295364810001 -2.188947321385536e+180 QLearner(pos=4.9e+179, bullets=8.9e+180, angle=3.4e+179, courage=1.0)
# -0.2824295364810001 2.188947321385536e+180 QLearner(pos=5.7e+179, bullets=8.9e+180, angle=3.2e+179, courage=1.0)
# -0.31381059609000006 -2.4554282234028092e+180 QLearner(pos=6.6e+179, bullets=8.8e+180, angle=3e+179, courage=1.0)
# -0.31381059609000006 2.4554282234028092e+180 QLearner(pos=7.5e+179, bullets=8.8e+180, angle=2.9e+179, courage=1.0)
# -0.3486784401000001 -2.739770150909572e+180 QLearner(pos=8.5e+179, bullets=8.8e+180, angle=2.8e+179, courage=1.0)
# -0.3486784401000001 2.739770150909572e+180 QLearner(pos=9.6e+179, bullets=8.7e+180, angle=2.8e+179, courage=1.0)
# -0.3874204890000001 -3.101396895979733e+180 QLearner(pos=1.1e+180, bullets=8.7e+180, angle=2.8e+179, courage=1.0)
# -0.3874204890000001 3.101396895979733e+180 QLearner(pos=1.2e+180, bullets=8.7e+180, angle=2.8e+179, courage=1.0)
# -0.4304672100000001 -3.500651951563324e+180 QLearner(pos=1.3e+180, bullets=8.6e+180, angle=2.8e+179, courage=1.0)
# -0.4304672100000001 3.500651951563324e+180 QLearner(pos=1.5e+180, bullets=8.6e+180, angle=2.8e+179, courage=1.0)
# -0.4782969000000001 -3.9108281968915386e+180 QLearner(pos=1.6e+180, bullets=8.5e+180, angle=2.8e+179, courage=1.0)
# -0.4782969000000001 3.9108281968915386e+180 QLearner(pos=1.8e+180, bullets=8.4e+180, angle=2.7e+179, courage=1.0)
# -0.531441 -4.384273181071899e+180 QLearner(pos=1.9e+180, bullets=8.3e+180, angle=2.7e+179, courage=1.0)
# -0.531441 4.384273181071899e+180 QLearner(pos=2.1e+180, bullets=8.2e+180, angle=2.7e+179, courage=1.0)
# -0.5904900000000001 -4.928781710708586e+180 QLearner(pos=2.3e+180, bullets=8.1e+180, angle=2.7e+179, courage=1.0)
# -0.5904900000000001 4.928781710708586e+180 QLearner(pos=2.5e+180, bullets=8e+180, angle=2.6e+179, courage=1.0)
# -0.6561 -6.379587343187735e+180 QLearner(pos=2.7e+180, bullets=7.8e+180, angle=2.6e+179, courage=1.0)
# -0.6561 6.379587343187735e+180 QLearner(pos=3e+180, bullets=7.6e+180, angle=2.6e+179, courage=1.0)
# -0.7290000000000001 -7.756205611294045e+180 QLearner(pos=3.3e+180, bullets=7.3e+180, angle=2.6e+179, courage=1.0)
# -0.7290000000000001 7.756205611294045e+180 QLearner(pos=3.6e+180, bullets=6.9e+180, angle=2.5e+179, courage=1.0)
# -0.81 -9.060708309155066e+180 QLearner(pos=4e+180, bullets=6.5e+180, angle=2.5e+179, courage=1.0)
# -0.81 9.060708309155066e+180 QLearner(pos=4.4e+180, bullets=5.9e+180, angle=2.4e+179, courage=1.0)
# -0.9 -1.0912933004933547e+181 QLearner(pos=4.8e+180, bullets=5.3e+180, angle=2.4e+179, courage=1.0)
# -0.9 1.0912933004933547e+181 QLearner(pos=5.3e+180, bullets=4.2e+180, angle=2.3e+179, courage=1.0)
# QLearner(pos=5.8e+180, bullets=3e+180, angle=2.3e+179, courage=1.0)
# Game 26
# -0.020275559590445275 5.916953907343798e+180 QLearner(pos=5.8e+180, bullets=3e+180, angle=2.3e+179, courage=1.0)
# -0.020275559590445275 -5.916953907343798e+180 QLearner(pos=5.6e+180, bullets=3e+180, angle=1e+179, courage=1.0)
# -0.022528399544939195 5.403751857744114e+180 QLearner(pos=5.4e+180, bullets=3e+180, angle=-2.5e+178, courage=1.0)
# -0.022528399544939195 -5.403751857744114e+180 QLearner(pos=5.3e+180, bullets=3e+180, angle=-1.4e+179, courage=1.0)
# -0.025031555049932437 4.94033906430263e+180 QLearner(pos=5.1e+180, bullets=3e+180, angle=-2.6e+179, courage=1.0)
# -0.025031555049932437 -4.94033906430263e+180 QLearner(pos=5e+180, bullets=3e+180, angle=-3.6e+179, courage=1.0)
# -0.027812838944369374 4.522610869918077e+180 QLearner(pos=4.8e+180, bullets=3e+180, angle=-4.7e+179, courage=1.0)
# -0.027812838944369374 -4.522610869918077e+180 QLearner(pos=4.7e+180, bullets=3e+180, angle=-5.7e+179, courage=1.0)
# -0.030903154382632636 4.1462745477988464e+180 QLearner(pos=4.6e+180, bullets=3e+180, angle=-6.6e+179, courage=1.0)
# -0.030903154382632636 -4.1462745477988464e+180 QLearner(pos=4.5e+180, bullets=3e+180, angle=-7.5e+179, courage=1.0)
# -0.03433683820292515 3.8083950457126036e+180 QLearner(pos=4.3e+180, bullets=3e+180, angle=-8.4e+179, courage=1.0)
# -0.03433683820292515 -3.8083950457126036e+180 QLearner(pos=4.2e+180, bullets=3e+180, angle=-9.2e+179, courage=1.0)
# -0.038152042447694615 3.5080323705279727e+180 QLearner(pos=4.1e+180, bullets=3e+180, angle=-1e+180, courage=1.0)
# -0.038152042447694615 -3.5080323705279727e+180 QLearner(pos=4e+180, bullets=3e+180, angle=-1.1e+180, courage=1.0)
# -0.04239115827521624 3.2468494888121265e+180 QLearner(pos=3.9e+180, bullets=3e+180, angle=-1.2e+180, courage=1.0)
# -0.04239115827521624 -3.2468494888121265e+180 QLearner(pos=3.8e+180, bullets=3e+180, angle=-1.2e+180, courage=1.0)
# -0.047101286972462485 3.019910514487444e+180 QLearner(pos=3.7e+180, bullets=3e+180, angle=-1.3e+180, courage=1.0)
# -0.047101286972462485 -3.019910514487444e+180 QLearner(pos=3.6e+180, bullets=3e+180, angle=-1.4e+180, courage=1.0)
# -0.05233476330273609 2.818806838539175e+180 QLearner(pos=3.5e+180, bullets=3e+180, angle=-1.4e+180, courage=1.0)
# -0.05233476330273609 -2.818806838539175e+180 QLearner(pos=3.5e+180, bullets=3e+180, angle=-1.5e+180, courage=1.0)
# -0.058149737003040096 2.6431625550473625e+180 QLearner(pos=3.4e+180, bullets=3e+180, angle=-1.5e+180, courage=1.0)
# -0.058149737003040096 -2.6431625550473625e+180 QLearner(pos=3.3e+180, bullets=3e+180, angle=-1.6e+180, courage=1.0)
# -0.06461081889226677 2.4818901511117323e+180 QLearner(pos=3.2e+180, bullets=3e+180, angle=-1.6e+180, courage=1.0)
# 26it [00:06,  4.17it/s]
# -0.06461081889226677 -2.4818901511117323e+180 QLearner(pos=3.1e+180, bullets=3e+180, angle=-1.7e+180, courage=1.0)
# -0.0717897987691853 2.3291787828963755e+180 QLearner(pos=3e+180, bullets=3e+180, angle=-1.7e+180, courage=1.0)
# -0.0717897987691853 -2.3291787828963755e+180 QLearner(pos=3e+180, bullets=3e+180, angle=-1.8e+180, courage=1.0)
# -0.07976644307687256 2.1809970026849606e+180 QLearner(pos=2.9e+180, bullets=3e+180, angle=-1.8e+180, courage=1.0)
# -0.07976644307687256 -2.1809970026849606e+180 QLearner(pos=2.8e+180, bullets=3e+180, angle=-1.9e+180, courage=1.0)
# -0.08862938119652507 2.0287785085669565e+180 QLearner(pos=2.7e+180, bullets=3e+180, angle=-1.9e+180, courage=1.0)
# -0.08862938119652507 -2.0287785085669565e+180 QLearner(pos=2.7e+180, bullets=3e+180, angle=-1.9e+180, courage=1.0)
# -0.09847709021836118 1.8737399376895443e+180 QLearner(pos=2.6e+180, bullets=3e+180, angle=-2e+180, courage=1.0)
# -0.09847709021836118 -1.8737399376895443e+180 QLearner(pos=2.5e+180, bullets=3e+180, angle=-2e+180, courage=1.0)
# -0.10941898913151242 1.6907994394761105e+180 QLearner(pos=2.5e+180, bullets=3e+180, angle=-2e+180, courage=1.0)
# -0.10941898913151242 -1.6907994394761105e+180 QLearner(pos=2.4e+180, bullets=3e+180, angle=-2.1e+180, courage=1.0)
# -0.12157665459056935 1.7465493943401512e+180 QLearner(pos=2.4e+180, bullets=3e+180, angle=-2.1e+180, courage=1.0)
# -0.12157665459056935 -1.7465493943401512e+180 QLearner(pos=2.3e+180, bullets=3e+180, angle=-2.1e+180, courage=1.0)
# -0.13508517176729928 1.8002408587949857e+180 QLearner(pos=2.2e+180, bullets=3e+180, angle=-2.2e+180, courage=1.0)
# -0.13508517176729928 -1.8002408587949857e+180 QLearner(pos=2.2e+180, bullets=3.1e+180, angle=-2.2e+180, courage=1.0)
# -0.15009463529699918 1.8586739121057147e+180 QLearner(pos=2.1e+180, bullets=3.1e+180, angle=-2.2e+180, courage=1.0)
# -0.15009463529699918 -1.8586739121057147e+180 QLearner(pos=2e+180, bullets=3.1e+180, angle=-2.2e+180, courage=1.0)
# -0.16677181699666577 1.8994135991119906e+180 QLearner(pos=2e+180, bullets=3.1e+180, angle=-2.2e+180, courage=1.0)
# -0.16677181699666577 -1.8994135991119906e+180 QLearner(pos=1.9e+180, bullets=3.1e+180, angle=-2.2e+180, courage=1.0)
# -0.18530201888518416 1.9357320670495995e+180 QLearner(pos=1.8e+180, bullets=3.1e+180, angle=-2.2e+180, courage=1.0)
# -0.18530201888518416 -1.9357320670495995e+180 QLearner(pos=1.8e+180, bullets=3.1e+180, angle=-2.2e+180, courage=1.0)
# -0.20589113209464907 1.9427106339106647e+180 QLearner(pos=1.7e+180, bullets=3.1e+180, angle=-2.2e+180, courage=1.0)
# -0.20589113209464907 -1.9427106339106647e+180 QLearner(pos=1.6e+180, bullets=3.1e+180, angle=-2.2e+180, courage=1.0)
# -0.2287679245496101 1.9274569529399703e+180 QLearner(pos=1.6e+180, bullets=3.1e+180, angle=-2.2e+180, courage=1.0)
# -0.2287679245496101 -1.9274569529399703e+180 QLearner(pos=1.5e+180, bullets=3.1e+180, angle=-2.2e+180, courage=1.0)
# -0.2541865828329001 1.8802588840522509e+180 QLearner(pos=1.4e+180, bullets=3.1e+180, angle=-2.2e+180, courage=1.0)
# -0.2541865828329001 -1.8802588840522509e+180 QLearner(pos=1.3e+180, bullets=3.1e+180, angle=-2.2e+180, courage=1.0)
# -0.2824295364810001 1.2836354930352043e+180 QLearner(pos=1.3e+180, bullets=3.2e+180, angle=-2.2e+180, courage=1.0)
# -0.2824295364810001 -1.2836354930352043e+180 QLearner(pos=1.2e+180, bullets=3.2e+180, angle=-2.1e+180, courage=1.0)
# -0.31381059609000006 6.93948430577097e+179 QLearner(pos=1.2e+180, bullets=3.2e+180, angle=-2.1e+180, courage=1.0)
# -0.31381059609000006 -6.93948430577097e+179 QLearner(pos=1.2e+180, bullets=3.2e+180, angle=-2.1e+180, courage=1.0)
# -0.3486784401000001 1.468571344425815e+179 QLearner(pos=1.1e+180, bullets=3.2e+180, angle=-2.1e+180, courage=1.0)
# -0.3486784401000001 -1.468571344425815e+179 QLearner(pos=1.1e+180, bullets=3.2e+180, angle=-2.1e+180, courage=1.0)
# -0.3874204890000001 -1.0983706213510917e+179 QLearner(pos=1.1e+180, bullets=3.2e+180, angle=-2.1e+180, courage=1.0)
# -0.3874204890000001 1.0983706213510917e+179 QLearner(pos=1.1e+180, bullets=3.2e+180, angle=-2.1e+180, courage=1.0)
# -0.4304672100000001 -3.773502258981118e+179 QLearner(pos=1.1e+180, bullets=3.2e+180, angle=-2.1e+180, courage=1.0)
# -0.4304672100000001 3.773502258981118e+179 QLearner(pos=1.1e+180, bullets=3.2e+180, angle=-2.1e+180, courage=1.0)
# -0.4782969000000001 -6.47882488593349e+179 QLearner(pos=1.2e+180, bullets=3.2e+180, angle=-2.1e+180, courage=1.0)
# -0.4782969000000001 6.47882488593349e+179 QLearner(pos=1.2e+180, bullets=3.2e+180, angle=-2.1e+180, courage=1.0)
# -0.531441 -9.42973855542203e+179 QLearner(pos=1.2e+180, bullets=3.2e+180, angle=-2.1e+180, courage=1.0)
# -0.531441 9.42973855542203e+179 QLearner(pos=1.2e+180, bullets=3.1e+180, angle=-2.1e+180, courage=1.0)
# -0.5904900000000001 -1.2672330328899157e+180 QLearner(pos=1.3e+180, bullets=3.1e+180, angle=-2.1e+180, courage=1.0)
# -0.5904900000000001 1.2672330328899157e+180 QLearner(pos=1.3e+180, bullets=3.1e+180, angle=-2.1e+180, courage=1.0)
# -0.6561 -1.9495157711255156e+180 QLearner(pos=1.4e+180, bullets=3e+180, angle=-2.1e+180, courage=1.0)
# -0.6561 1.9495157711255156e+180 QLearner(pos=1.5e+180, bullets=3e+180, angle=-2.1e+180, courage=1.0)
# -0.7290000000000001 -2.6314001696561374e+180 QLearner(pos=1.6e+180, bullets=2.9e+180, angle=-2.1e+180, courage=1.0)
# -0.7290000000000001 2.6314001696561374e+180 QLearner(pos=1.7e+180, bullets=2.8e+180, angle=-2.1e+180, courage=1.0)
# -0.81 -3.326771666304392e+180 QLearner(pos=1.8e+180, bullets=2.6e+180, angle=-2.1e+180, courage=1.0)
# -0.81 3.326771666304392e+180 QLearner(pos=1.9e+180, bullets=2.4e+180, angle=-2.1e+180, courage=1.0)
# -0.9 -4.323133090748461e+180 QLearner(pos=2.1e+180, bullets=2.2e+180, angle=-2.1e+180, courage=1.0)
# -0.9 4.323133090748461e+180 QLearner(pos=2.3e+180, bullets=1.8e+180, angle=-2.1e+180, courage=1.0)
# QLearner(pos=2.5e+180, bullets=1.3e+180, angle=-2.1e+180, courage=1.0)
# Game 27
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-215-e42311f26ecd> in <module>
#       5     if g.result != 0:
#       6         winner = 1 if g.result == 1 else -1
# ----> 7         q.learn(feat_df(g.to_df()), winner, alpha=1/(10 + n_round))
#       8         print(q)
#
# <ipython-input-178-872f3aea43e8> in feat_df(game_df)
#       3     for row in game_df.to_dict(orient='records'):
#       4         pos, bullets, angle = feats(row, 1)
# ----> 5         pos2, bullets2, angle2 = feats(row, 2)
#       6         rows.append({
#       7             'pos1': pos,
#
# <ipython-input-177-3a03be529366> in feats(row, player)
#      11         bullets['y'] /= height
#      12         leeway = (player_r + bullet_r) / max(width, height)
# ---> 13         bullet_score = sum(np.log(np.linalg.norm(vec - pos) - leeway) for vec in bullets.query(f'player != "Player {player}"')[['x', 'y']].values)
#      14
#      15     curr_angle = np.arctan2(row[f'y{3-player}'] - row[f'y{player}'],
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1545             if len(ax) or not len(key):
#    1546                 key = self._convert_for_reindex(key, axis)
# -> 1547             indexer = ax.get_indexer_for(key)
#    1548             keyarr = ax.reindex(keyarr)[0]
#    1549         else:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_indexer_for(self, target, **kwargs)
#    4500         """
#    4501         if self.is_unique:
# -> 4502             return self.get_indexer(target, **kwargs)
#    4503         indexer, _ = self.get_indexer_non_unique(target, **kwargs)
#    4504         return indexer
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    2707     def get_indexer(self, target, method=None, limit=None, tolerance=None):
#    2708         method = missing.clean_reindex_fill_method(method)
# -> 2709         target = ensure_index(target)
#    2710         if tolerance is not None:
#    2711             tolerance = self._convert_tolerance(tolerance, target)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    5356             index_like = copy(index_like)
#    5357
# -> 5358     return Index(index_like)
#    5359
#    5360
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     406                 new_data, new_dtype = _maybe_cast_data_without_dtype(subarr)
#     407                 if new_dtype is not None:
# --> 408                     return cls(
#     409                         new_data, dtype=new_dtype, copy=False, name=name, **kwargs
#     410                     )
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     393             elif is_float_dtype(data.dtype):
#     394                 return Float64Index(data, copy=copy, dtype=dtype, name=name)
# --> 395             elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#     396                 subarr = data.astype("object")
#     397             else:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/common.py in is_bool_dtype(arr_or_dtype)
#    1484         # now we use the special definition for Index
#    1485
# -> 1486     if isinstance(arr_or_dtype, ABCIndexClass):
#    1487
#    1488         # TODO(jreback)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/generic.py in _check(cls, inst)
#      10     @classmethod  # type: ignore
#      11     def _check(cls, inst) -> bool:
# ---> 12         return getattr(inst, attr, "_typ") in comp
#      13
#      14     dct = dict(__instancecheck__=_check, __subclasscheck__=_check)
#
# KeyboardInterrupt:
